# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image

# %%
data = np.loadtxt('m.txt', dtype = float) 
print(data[:5])
# Out:
# [0.500404 0.500271 0.500244 0.500273 0.500102]

# %%
sns.set_style("darkgrid")
ax = sns.lineplot(data = data, color = 'black') 
ax.set(xlabel ='Number of Iterations', ylabel = 'Mean magnetisation per unit spin')
plt.show()

# %%
N = 100 
M = 100 
data = np.loadtxt('Ainit.txt', dtype = float)

# %%
data = data.reshape(N+2, -1)
data.shape
# Out:
# (102, 102)

# %%
maxd = np.max(data)
mind = np.min(data) 

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        data[i][j] = 255/(maxd-mind)*data[i][j] - 255*mind/(maxd-mind) 

data = data.astype(np.uint8)

# %%
data = Image.fromarray(data)
data.save('Initial-Matrix.png')

# %%
N = 100 
M = 100 
data = np.loadtxt('A.txt', dtype = float)

# %%
data = data.reshape(N+2, -1)
data.shape
# Out:
# (102, 102)

# %%
plt.imshow(data, interpolation='bilinear')
plt.show()
